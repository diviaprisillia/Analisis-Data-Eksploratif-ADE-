# %%
import pandas as pd
df = pd.read_csv('Data mobil bekas bmw.csv', delimiter=',')
df
# Out:
#            model  year  price transmission  mileage fuelType  tax   mpg  \
# 0       5 Series  2014  11200    Automatic    67068   Diesel  125  57.6
# 1       6 Series  2018  27000    Automatic    14827   Petrol  145  42.8
# 2       5 Series  2016  16000    Automatic    62794   Diesel  160  51.4
# 3       1 Series  2017  12750    Automatic    26676   Diesel  145  72.4
# 4       7 Series  2014  14500    Automatic    39554   Diesel  160  50.4
# ...          ...   ...    ...          ...      ...      ...  ...   ...
# 10776         X3  2016  19000    Automatic    40818   Diesel  150  54.3
# 10777   5 Series  2016  14600    Automatic    42947   Diesel  125  60.1
# 10778   3 Series  2017  13100       Manual    25468   Petrol  200  42.8
# 10779   1 Series  2014   9930    Automatic    45000   Diesel   30  64.2
# 10780         X1  2017  15981    Automatic    59432   Diesel  125  57.6
#
#        engineSize
# 0             2.0
# 1             2.0
# 2             3.0
# 3             1.5
# ...

# %%
df.columns
# Out:
# Index(['model', 'year', 'price', 'transmission', 'mileage', 'fuelType', 'tax',
#        'mpg', 'engineSize'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10781 entries, 0 to 10780
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   model         10781 non-null  object
#  1   year          10781 non-null  int64
#  2   price         10781 non-null  int64
#  3   transmission  10781 non-null  object
#  4   mileage       10781 non-null  int64
#  5   fuelType      10781 non-null  object
#  6   tax           10781 non-null  int64
#  7   mpg           10781 non-null  float64
#  8   engineSize    10781 non-null  float64
# dtypes: float64(2), int64(4), object(3)
# memory usage: 758.2+ KB

# %%
df.describe()
# Out:
#                year          price        mileage           tax           mpg  \
# count  10781.000000   10781.000000   10781.000000  10781.000000  10781.000000
# mean    2017.078935   22733.408867   25496.986550    131.702068     56.399035
# std        2.349038   11415.528189   25143.192559     61.510755     31.336958
# min     1996.000000    1200.000000       1.000000      0.000000      5.500000
# 25%     2016.000000   14950.000000    5529.000000    135.000000     45.600000
# 50%     2017.000000   20462.000000   18347.000000    145.000000     53.300000
# 75%     2019.000000   27940.000000   38206.000000    145.000000     62.800000
# max     2020.000000  123456.000000  214000.000000    580.000000    470.800000
#
#          engineSize
# count  10781.000000
# mean       2.167767
# std        0.552054
# min        0.000000
# 25%        2.000000
# 50%        2.000000
# 75%        2.000000
# max        6.600000

# %% [markdown]
# # Transformasi Data

# %%
import pandas as pd

df = pd.read_csv("Data mobil bekas bmw.csv")
df.drop_duplicates(inplace=True)

print("Info Dataset setelah Deteksi dan Penanganan Duplikasi:")
print(df.info())
# Out:
# Info Dataset setelah Deteksi dan Penanganan Duplikasi:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10664 entries, 0 to 10780
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   model         10664 non-null  object
#  1   year          10664 non-null  int64
#  2   price         10664 non-null  int64
#  3   transmission  10664 non-null  object
#  4   mileage       10664 non-null  int64
#  5   fuelType      10664 non-null  object
#  6   tax           10664 non-null  int64
#  7   mpg           10664 non-null  float64
#  8   engineSize    10664 non-null  float64
# dtypes: float64(2), int64(4), object(3)
# memory usage: 833.1+ KB
# None

# %% [markdown]
# Identifikasi dan Penanggulangan Nilai yang Hilang pada Variabel Harga, Transmisi, dan Bahan Bakar

# %%
import pandas as pd
from sklearn.impute import SimpleImputer

df = pd.read_csv("Data mobil bekas bmw.csv")

df['price'].fillna(df['price'].median(), inplace=True)

transmission_imputer = SimpleImputer(strategy='most_frequent')
df['transmission'] = transmission_imputer.fit_transform(df[['transmission']])

fuel_type_imputer = SimpleImputer(strategy='most_frequent')
df['fuelType'] = fuel_type_imputer.fit_transform(df[['fuelType']])

print("Info Dataset setelah Penanggulangan Nilai yang Hilang:")
print(df.info())
# Out:
# Info Dataset setelah Penanggulangan Nilai yang Hilang:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10781 entries, 0 to 10780
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   model         10781 non-null  object
#  1   year          10781 non-null  int64
#  2   price         10781 non-null  int64
#  3   transmission  10781 non-null  object
#  4   mileage       10781 non-null  int64
#  5   fuelType      10781 non-null  object
#  6   tax           10781 non-null  int64
#  7   mpg           10781 non-null  float64
#  8   engineSize    10781 non-null  float64
# dtypes: float64(2), int64(4), object(3)
# memory usage: 758.2+ KB
# None

# %% [markdown]
# Menentukan Metode Imputasi yang Paling Efektif untuk Variabel Price

# %%
import pandas as pd
from sklearn.impute import SimpleImputer

df = pd.read_csv("Data mobil bekas bmw.csv")

custom_imputer = SimpleImputer(strategy='mean') 
df['price'] = custom_imputer.fit_transform(df[['price']])

print("Info Dataset setelah Menentukan Metode Imputasi:")
print(df.info())
# Out:
# Info Dataset setelah Menentukan Metode Imputasi:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10781 entries, 0 to 10780
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   model         10781 non-null  object
#  1   year          10781 non-null  int64
#  2   price         10781 non-null  float64
#  3   transmission  10781 non-null  object
#  4   mileage       10781 non-null  int64
#  5   fuelType      10781 non-null  object
#  6   tax           10781 non-null  int64
#  7   mpg           10781 non-null  float64
#  8   engineSize    10781 non-null  float64
# dtypes: float64(3), int64(3), object(3)
# memory usage: 758.2+ KB
# None

# %% [markdown]
# # Integrasi Data

# %% [markdown]
# Deteksi Outlier pada Variabel Engine Size, Mileage, Tax, dan MPG

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv("Data mobil bekas bmw.csv")

plt.figure(figsize=(10, 6))
sns.boxplot(x='engineSize', data=df)  
plt.title('Boxplot Variabel Engine Size')
plt.show()

plt.figure(figsize=(10, 6))
sns.boxplot(x='mileage', data=df) 
plt.title('Boxplot Variabel Mileage')
plt.show()

plt.figure(figsize=(10, 6))
sns.boxplot(x='tax', data=df)  
plt.title('Boxplot Variabel Tax')
plt.show()

plt.figure(figsize=(10, 6))
sns.boxplot(x='mpg', data=df)  
plt.title('Boxplot Variabel MPG')
plt.show()

# %% [markdown]
# Penanganan Outlier yang Efektif

# %%
import pandas as pd
from scipy.stats import zscore

df = pd.read_csv("Data mobil bekas bmw.csv")
threshold = 3
z_scores = zscore(df[['engineSize', 'mileage', 'tax', 'mpg']])

outliers = (abs(z_scores) > threshold).any(axis=1)

df.loc[outliers, ['engineSize', 'mileage', 'tax', 'mpg']] = df.median()

print("Info Dataset setelah Penanganan Outlier:")
print(df.info())
# Out:
# Info Dataset setelah Penanganan Outlier:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10781 entries, 0 to 10780
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   model         10781 non-null  object
#  1   year          10781 non-null  int64
#  2   price         10781 non-null  int64
#  3   transmission  10781 non-null  object
#  4   mileage       10430 non-null  float64
#  5   fuelType      10781 non-null  object
#  6   tax           10430 non-null  float64
#  7   mpg           10430 non-null  float64
#  8   engineSize    10430 non-null  float64
# dtypes: float64(4), int64(2), object(3)
# memory usage: 758.2+ KB
# None
# ...

# %% [markdown]
# # Distribusi Harga Mobil

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# menentukan nilai dari a dan b berdasarkan mean dan standard deviation
mean = df['price'].mean()
std_deviation = df['price'].std()
a = mean - (np.sqrt(3) * std_deviation)
b = mean + (np.sqrt(3) * std_deviation)

# Menghitung probabilitas x < 5 dan presentasenya
prob = 1 / (b - a)
prob_percent = prob * 100

print(f"Mean (rata-rata): {mean:.2f}")
print(f"Standard Deviation (deviasi standar): {std_deviation:.2f}")
print(f"a (batas bawah distribusi uniform): {a:.2f}")
print(f"b (batas atas distribusi uniform): {b:.2f}")
print(f"Probabilitas x < 5: {prob:.2f}")
print(f"Persentase probabilitas x < 5: {prob_percent:.2f}%")

# visualisasi histogram
sns.set(color_codes=True)
sns.set(rc={'figure.figsize': (10, 6)})
ax = sns.histplot(df['price'], bins=100, color='green', kde=True)
ax.set(xlabel='Data Distribution', ylabel='Frequency')

plt.show()
# Out:
# Mean (rata-rata): 22733.41
# Standard Deviation (deviasi standar): 11415.53
# a (batas bawah distribusi uniform): 2961.13
# b (batas atas distribusi uniform): 42505.68
# Probabilitas x < 5: 0.00
# Persentase probabilitas x < 5: 0.00%

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# menghitung nilai a dan b
a = df['price'].min()
b = df['price'].max()

# Menghitung nilai mean dan standard deviation (sigma)
mean = df['price'].mean()
sigma = df['price'].std()

# Membangun distribusi normal berdasarkan rata-rata dan deviasi standar
price = np.linspace(a, b, 100)
pdf = (1 / (sigma * np.sqrt(2 * np.pi))) * np.exp(-0.5 * ((price - mean) / sigma) ** 2)

print(f"Nilai a: {a}")
print(f"Nilai b: {b}")
print(f"Hasil perhitungan f(price) dari nilai x: {pdf}")

# visualisasi histogram
sns.set(color_codes=True)
sns.set(rc={'figure.figsize': (10, 6)})
ax = sns.histplot(df['price'], bins=100, color='green', kde=True)
ax.set(xlabel='Data Distribution', ylabel='Frequency')
ax.plot(price, pdf, color='red', label='Distribusi Normal')
ax.legend()

plt.show()
# Out:
# Nilai a: 1200
# Nilai b: 123456
# Hasil perhitungan f(price) dari nilai x: [5.89868297e-06 7.19176672e-06 8.66630171e-06 1.03216634e-05
#  1.21501954e-05 1.41362594e-05 1.62556158e-05 1.84752372e-05
#  2.07536409e-05 2.30417919e-05 2.52845878e-05 2.74228876e-05
#  2.93959951e-05 3.11444615e-05 3.26130309e-05 3.37535282e-05
#  3.45274787e-05 3.49082626e-05 3.48826346e-05 3.44514892e-05
#  3.36298088e-05 3.24457990e-05 3.09392816e-05 2.91594719e-05
#  2.71623137e-05 2.50075729e-05 2.27558994e-05 2.04660552e-05
#  1.81924821e-05 1.59833366e-05 1.38790779e-05 1.19116373e-05
#  1.01041546e-05 8.47122429e-06 7.01956268e-06 5.74899075e-06
#  4.65361917e-06 3.72312610e-06 2.94403067e-06 2.30088329e-06
#  1.77731550e-06 1.35691344e-06 1.02389975e-06 7.63625467e-07
#  5.62886780e-07 4.10090182e-07 2.95294509e-07 2.10159510e-07
#  1.47829259e-07 1.02775461e-07 7.06213701e-08 4.79623577e-08
#  3.21945667e-08 2.13590692e-08 1.40055361e-08 9.07684315e-09
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Menghitung rata-rata (μ) dan deviasi standar (σ)
mean = df['price'].mean()
std_deviation = df['price'].std()
median = df['price'].median()

# Menghitung skewness
skewness = 3 * (mean - median) / std_deviation

# Membangun distribusi normal berdasarkan rata-rata dan deviasi standar
x = np.linspace(df['price'].min(), df['price'].max(), 100)
pdf = (1 / (std_deviation * np.sqrt(2 * np.pi))) * np.exp(-0.5 * ((price - mean) / std_deviation) ** 2)

# Visualisasi histogram
sns.set(color_codes=True)
sns.set(rc={'figure.figsize': (10, 6)})
ax = sns.histplot(df['price'], bins=10, color='green', kde=True)
ax.set(xlabel='Data Distribution', ylabel='Frequency')

# Tambahkan label skewness ke plot
plt.text(0.8, 15, f'Skewness: {skewness:.2f}', fontsize=12, color='red')

# Visualisasi distribusi normal
plt.plot(x, pdf, label='Distribusi Normal', color='blue')
plt.xlabel('price')
plt.ylabel('f(price)')
plt.legend()
plt.title('Distribusi Normal vs. Data')

plt.show()

# Menentukan kecondongan data
if skewness > 0:
    print("Data memiliki kecondongan ke arah positif (right-skewed).")
elif skewness < 0:
    print("Data memiliki kecondongan ke arah negatif (left-skewed).")
else:
    print("Data memiliki distribusi simetris (tidak memiliki kecondongan).")
# Out:
# Data memiliki kecondongan ke arah positif (right-skewed).

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Menghitung nilai rata-rata dan deviasi standar
mean = df['price'].mean()
std_deviation = df['price'].std()

# Membangun distribusi normal berdasarkan rata-rata dan deviasi standar
Price = np.linspace(df['price'].min(), df['price'].max(), 100)
pdf = (1 / (std_deviation * np.sqrt(2 * np.pi))) * np.exp(-0.5 * ((Price - mean) / std_deviation) ** 2)

# Menghitung kurtosis data
n = len(df['price'])  # Jumlah data
kurtosis = (1 / n) * sum((df['price'] - mean) ** 4) / (std_deviation ** 4)

print("Kurtosis: {:.2f}".format(kurtosis))

# Visualisasi data dengan histogram dan KDE
sns.set(color_codes=True)
sns.set(rc={'figure.figsize': (10, 6)})
ax = sns.histplot(df['price'], bins=10, color='green', kde=True)
ax.set(xlabel='Data Distribution', ylabel='Frequency')

plt.show()

# Menentukan jenis kurtosis
if kurtosis < 0:
    jenis_kurtosis = 'platykurtic'
elif kurtosis > 0:
    jenis_kurtosis = 'leptokurtic'
else:
    jenis_kurtosis = 'mesokurtic'

print(f"Jenis kurtosis dari distribusi data adalah: {jenis_kurtosis}")
# Out:
# Kurtosis: 7.02
# Jenis kurtosis dari distribusi data adalah: leptokurtic

# %% [markdown]
# # Analisis Hubungan: Engine Size, Mileage, MPG terhadap Harga Mobil

# %% [markdown]
# Bagaimana kita dapat menganalisis hubungan antara variabel independen seperti Engine Size, Mileage, dan MPG dengan harga mobil untuk menentukan faktor-faktor utama yang mempengaruhi harga?
#
#
# Analisis Hubungan dengan Variabel Independen:
#    - Menggunakan teknik analisis korelasi, seperti korelasi Pearson atau Spearman, untuk memahami hubungan antara variabel independen (Engine Size, Mileage, MPG) dengan harga mobil.
#    - Membuat scatter plot atau pair plot untuk visualisasi hubungan antar variabel.

# %%
# 1. Memuat matriks korelasi

# Analisis Hubungan antara Engine Size, Mileage, MPG, dan Harga
independent_variables = ['engineSize', 'mileage', 'mpg']
dependent_variable = 'price'

# Korelasi antara Variabel Independen dan Harga
correlation_matrix = df[independent_variables + [dependent_variable]].corr()
print('\nCorrelation Matrix:\n', correlation_matrix)
# Out:
# Correlation Matrix:
#              engineSize   mileage       mpg     price
# engineSize    1.000000 -0.002540 -0.399844  0.460196
# mileage      -0.002540  1.000000  0.118609 -0.605397
# mpg          -0.399844  0.118609  1.000000 -0.204882
# price         0.460196 -0.605397 -0.204882  1.000000

# %%
# 2. Membuat visualisasi matriks korelasi

import seaborn as sns
import matplotlib.pyplot as plt

correlation_matrix = df[['engineSize', 'mileage', 'mpg', 'price']].corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Matriks Korelasi')
plt.show()

# %%
# 3. Memuat scatterplot untuk  visualisasi hubungan antar variabel Engine Size, Mileage, MPG

# Visualisasi Scatter Plot untuk Hubungan antara Variabel Independen dan Harga
plt.figure(figsize=(15, 5))
for i, variable in enumerate(independent_variables, 1):
    plt.subplot(1, 3, i)
    sns.scatterplot(x=df[variable], y=df[dependent_variable])
    plt.title(f'Scatter Plot for {variable} vs. {dependent_variable}')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Tren Harga Mobil

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.metrics import mean_squared_error
import numpy as np

df = pd.read_csv('Data mobil bekas bmw.csv')
print(df.head())

# Visualisasi time series untuk melihat tren seiring waktu
plt.figure(figsize=(12, 6))
plt.scatter(df['year'], df['price'], label='Data Asli')
plt.title('Tren Harga Mobil Bekas Berdasarkan Tahun Pembuatan')
plt.xlabel('Tahun Pembuatan')
plt.ylabel('Harga Jual')

# Regresi Linier
X_linier = df[['year']].values
y_linier = df['price'].values
lin_reg = LinearRegression()
lin_reg.fit(X_linier, y_linier)
y_linier_pred = lin_reg.predict(X_linier)
plt.plot(df['year'], y_linier_pred, label='Regresi Linier', color='red')

plt.legend()
plt.show()

# Evaluasi kinerja model
mse_linier = mean_squared_error(y_linier, y_linier_pred)
print(f'Mean Squared Error (Regresi Linier): {mse_linier}')
# Out:
#        model  year  price transmission  mileage fuelType  tax   mpg  \
# 0   5 Series  2014  11200    Automatic    67068   Diesel  125  57.6
# 1   6 Series  2018  27000    Automatic    14827   Petrol  145  42.8
# 2   5 Series  2016  16000    Automatic    62794   Diesel  160  51.4
# 3   1 Series  2017  12750    Automatic    26676   Diesel  145  72.4
# 4   7 Series  2014  14500    Automatic    39554   Diesel  160  50.4
#
#    engineSize
# 0         2.0
# 1         2.0
# 2         3.0
# 3         1.5
# 4         3.0
# Mean Squared Error (Regresi Linier): 79605306.35577288

# %%
# Membaca dataset (ganti 'nama_file.csv' dengan nama file dataset yang sesuai)
df = pd.read_csv('Data mobil bekas bmw.csv')

# Menampilkan struktur dataset
print(df.head())

# Visualisasi time series atau line plot untuk melihat tren seiring waktu
plt.figure(figsize=(12, 6))
plt.scatter(df['year'], df['price'], label='Data Asli')
plt.title('Tren Harga Mobil Bekas Berdasarkan Tahun Pembuatan')
plt.xlabel('Tahun Pembuatan')
plt.ylabel('Harga Jual')

plt.legend()
plt.show()

# Evaluasi kinerja model
mse_linier = mean_squared_error(y_linier, y_linier_pred)
print(f'Mean Squared Error (Regresi Linier): {mse_linier}')
# Out:
#        model  year  price transmission  mileage fuelType  tax   mpg  \
# 0   5 Series  2014  11200    Automatic    67068   Diesel  125  57.6
# 1   6 Series  2018  27000    Automatic    14827   Petrol  145  42.8
# 2   5 Series  2016  16000    Automatic    62794   Diesel  160  51.4
# 3   1 Series  2017  12750    Automatic    26676   Diesel  145  72.4
# 4   7 Series  2014  14500    Automatic    39554   Diesel  160  50.4
#
#    engineSize
# 0         2.0
# 1         2.0
# 2         3.0
# 3         1.5
# 4         3.0
# Mean Squared Error (Regresi Linier): 79605306.35577288

# %%
# Regresi Linier
X_linier = df[['year']].values
y_linier = df['price'].values
lin_reg = LinearRegression()
lin_reg.fit(X_linier, y_linier)
y_linier_pred = lin_reg.predict(X_linier)
plt.plot(df['year'], y_linier_pred, label='Regresi Linier', color='red')
print(f'Mean Squared Error (Regresi Linier): {mse_linier}')
# Out:
# Mean Squared Error (Regresi Linier): 79605306.35577288

# %% [markdown]
# # Pengujian Hipotesis

# %% [markdown]
# Perbedaan Harga antara Mobil dengan Transmisi Manual dan Otomatis

# %%
import pandas as pd
from scipy.stats import ttest_ind

df = pd.read_csv("Data mobil bekas bmw.csv")

manual_cars = df[df['transmission'] == 'Manual']['price']

automatic_cars = df[df['transmission'] == 'Automatic']['price']

t_stat, p_value = ttest_ind(manual_cars, automatic_cars)

print(f'Test Statistic: {t_stat}')
print(f'P-value: {p_value}')

alpha = 0.05

if p_value < alpha:
    print("Terdapat perbedaan signifikan dalam harga antara mobil dengan transmisi manual dan otomatis.")
else:
    print("Tidak terdapat perbedaan signifikan dalam harga antara mobil dengan transmisi manual dan otomatis.")
# Out:
# Test Statistic: -32.12114994772356
# P-value: 2.5139984532092125e-209
# Terdapat perbedaan signifikan dalam harga antara mobil dengan transmisi manual dan otomatis.

# %% [markdown]
# Perbedaan Harga antara Mobil dengan Bahan Bakar Petrol dan Diesel

# %%
import pandas as pd
from scipy.stats import ttest_ind

df = pd.read_csv("Data mobil bekas bmw.csv")

petrol_cars = df[df['fuelType'] == 'Petrol']['price']

diesel_cars = df[df['fuelType'] == 'Diesel']['price']

t_stat, p_value = ttest_ind(petrol_cars, diesel_cars)

print(f'Test Statistic: {t_stat}')
print(f'P-value: {p_value}')

alpha = 0.05

if p_value < alpha:
    print("Terdapat perbedaan signifikan dalam harga antara mobil dengan bahan bakar petrol dan diesel.")
else:
    print("Tidak terdapat perbedaan signifikan dalam harga antara mobil dengan bahan bakar petrol dan diesel.")
# Out:
# Test Statistic: 10.947761139665987
# P-value: 9.636305621358734e-28
# Terdapat perbedaan signifikan dalam harga antara mobil dengan bahan bakar petrol dan diesel.

# %% [markdown]
# Visualisasi Boxplot

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv("Data mobil bekas bmw.csv")

plt.figure(figsize=(12, 6))
sns.boxplot(x='transmission', y='price', data=df)
plt.title('Perbedaan Harga antara Mobil dengan Transmisi Manual dan Otomatis')
plt.show()

plt.figure(figsize=(12, 6))
sns.boxplot(x='fuelType', y='price', data=df)
plt.title('Perbedaan Harga antara Mobil dengan Bahan Bakar Petrol dan Diesel')
plt.show()
